# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import urllib.request

# %%
response = requests.get('https://scholenopdekaart.nl/zoeken/basisscholen?zoektermen=2512&weergave=Lijst')
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="nl-NL">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="2512 - Zoeken | Scholen op de kaart" name="title"/>
#   <meta content="Zoek je een school bij jou in de buurt? Vind hier informatie om een geschikte school te kiezen." name="description"/>
#   <meta content="2512 - Zoeken | Scholen op de kaart" property="og:title"/>
#   <meta content="Zoek je een school bij jou in de buurt? Vind hier informatie om een geschikte school te kiezen." property="og:description"/>
#   <meta content="https://scholenopdekaart.nl/zoeken/basisscholen/?zoektermen=2512&amp;weergave=Lijst" property="og:url"/>
#   <meta content="nl_NL" property="og:locale"/>
#   <meta content="https://scholenopdekaart.nl/images/og-default-image.png" property="og:image"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
components = BeautifulSoup(response.content)
content = components.findAll('article', attrs={"class": 'zoekresultaat'})
content
# Out:
# []

# %%
soup.find('h3', class_='zoekresultaat-title')
