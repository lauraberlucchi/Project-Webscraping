# %%
import time

# getpass - to input our password without showing it in the notebook
from getpass import getpass

# Juicy stuff - these are the Classes we will use for interaction with a webpage:
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common import NoSuchElementException, ElementClickInterceptedException

# libraries for interacting with the operating system (OS)
import pathlib
import os
from os.path import join

import pandas as pd
import random
import re
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

url= 'https://scholenopdekaart.nl/zoeken/basisscholen?zoektermen=Den%20Haag&weergave=Lijst'

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get('https://scholenopdekaart.nl/zoeken/basisscholen?zoektermen=Den%20Haag&weergave=Lijst')

# %%
import pickle
cookies_dir = 'saved_cookies'
lis_dir = os.listdir()

if cookies_dir not in lis_dir:
    os.mkdir(cookies_dir)
else:
    pass # os.removedirs(cookies_dir) --> to remove a directory

save_location = cookies_dir + '/cookies.pkl'
pickle.dump(driver.get_cookies() , open(save_location,"wb"))

# %%
button_search = driver.find_element(By.CLASS_NAME, 'zoeken-resultaten-lijst-meer')
button_search.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\35196\Ironhack - aulas\W07\instagram-projectbase.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/35196/Ironhack%20-%20aulas/W07/instagram-projectbase.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> button_search = driver.find_element(By.CLASS_NAME, 'zoeken-resultaten-lijst-meer')
#       <a href='vscode-notebook-cell:/c%3A/Users/35196/Ironhack%20-%20aulas/W07/instagram-projectbase.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> button_search.click()
#
# File d:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:738, in WebDriver.find_element(self, by, value)
#     735     by = By.CSS_SELECTOR
#     736     value = f'[name="{value}"]'
# --> 738 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File d:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File d:\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".zoeken-resultaten-lijst-meer"}
#   (Session info: chrome=116.0.5845.188); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x002C37C3+48947]
# 	(No symbol) [0x00258551]
# 	(No symbol) [0x0015C92D]
# 	(No symbol) [0x00189E38]
# 	(No symbol) [0x00189EFB]
# 	(No symbol) [0x001B8EF2]
# 	(No symbol) [0x001A50D4]
# 	(No symbol) [0x001B75DA]
# 	(No symbol) [0x001A4E86]
# 	(No symbol) [0x001816C7]
# 	(No symbol) [0x0018284D]
# 	GetHandleVerifier [0x0050FDF9+2458985]
# 	GetHandleVerifier [0x0055744F+2751423]
# 	GetHandleVerifier [0x00551361+2726609]
# 	GetHandleVerifier [0x00340680+560624]
# 	(No symbol) [0x0026238C]
# 	(No symbol) [0x0025E268]
# 	(No symbol) [0x0025E392]
# 	(No symbol) [0x002510B7]
# 	BaseThreadInitThunk [0x7617FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77307B1E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77307AEE+238]
# 	(No symbol) [0x00000000]

# %%
html = driver.page_source
soup = BeautifulSoup(html)
soup.find_all(attrs={'class': re.compile(r'zoekresultaat-title')})
# Out:
# [<h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/8268/bernardusschool/">Bernardusschool</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/8269/basisschool-aquamarijn/">Basisschool Aquamarijn</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/4704/de-drie-linden/">De Drie Linden</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/8270/john-f-kennedy-montessorischool-voor-basisonderwijs/">John F Kennedy montessorischool voor basisonderwijs</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/4705/rk-basisschool-de-parkiet/">RK Basisschool De Parkiet</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/
a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/11878/protestants-christelijke-basisschool-de-oranjeschool/">Protestants Christelijke Basisschool De Oranjeschool</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/24263/protestants-christelijke-basisschool-de-oranjeschool-locatie-de-meerpaal/">Protestants Christelijke Basisschool De Oranjeschool locatie De Meerpaal</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/11879/de-gantel/">De Gantel</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/26373/cbs-de-waterlelie/">CBS De Waterlelie</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/8111/vereniging-willem-de-zwijgerschool/">Vereniging Willem de Zwijgerschool</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/8424/octantschool-fontein/">Octantschool Fontein</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/12151/octantschool-zonnestraal/">Octantschool Zonnestraal</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/12380/schoolvereniging-wolters/">Schoolvereniging Wolters</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/8619/ivio-instituut-voor-individueel-onderwijs/">IVIO Instituut voor Individueel Onderwijs</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/8620/internationale-basisschool-stichting-haagsche-schoolvereeniging/">Internationale basisschool Stichting Haagsche Schoolvereeniging</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/12381/willemspark/">Willemspark</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/12382/montessori-waalsdorp/">Montessori Waalsdorp</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/8621/de-vrije-school-den-haag/">De Vrije School Den Haag</a></h3>,
#  <h3 class="zoekresultaat-title"><a href="/basisscholen/den-haag/26854/iwsth-international-waldorf-school-the-hague/">IWSTH International Waldorf School The Hague</a></h3>]

# %%
school_list_dirty = soup.find_all(attrs={'class': re.compile(r'zoekresultaat-title')})
school_list_clean = [job.text.strip() for job in school_list_dirty]
school_list_clean
# Out:
# ['Bernardusschool',
#  'Basisschool Aquamarijn',
#  'De Drie Linden',
#  'John F Kennedy montessorischool voor basisonderwijs',
#  'RK Basisschool De Parkiet',
#  'Koos Meindertsschool',
#  'Katholieke Basisschool De Jonge Wereld',
#  'Basisschool Grote Beer',
#  'Carolusschool',
#  'KC Toermalijn',
#  'Basisschool Onze Wereld',
#  'Paschalisschool',
#  'Basisschool Statenkwartier',
#  'Kindcentrum Bamboe',
#  'Jeroen',
#  'rkbs De Regenboog',
#  'Het Lichtbaken',
#  "Basisschool 't Palet",
#  'Kindcentrum SPELEON',
#  'De Vuurvlinder',
#  'Liduina',
#  'De Triangel',
#  'De Opperd',
#  'SBO Aquamarijn',
#  'Speciaal Basisonderwijs Merlijn',
#  'Nutsschool Morgenstond',
#  'Nutsschool M.M.Boldingh',
#  'Nutsschool Laan van Poot',
#  'Nutsbasisschool Bezuidenhout',
#  'Nutsschool Zorgvliet',
#  'Nutsschool Woonstede',
#  'Prot Chr Basisschool De Vlieger',
#  'Rooms Katholieke Basisschool De Fontein',
#  'Kindcentrum Balans',
#  'Rooms Katholieke Basisschool De Paradijsvogel',
#  'RKBS De Bras',
#  'SBO Het Avontuur',
#  'KC De Binck',
#  'Cor Emousschool',
#  'Shri Vishnu School',
#  'Duinoord-Basisschool Protestants Christelijk Onderwijs',
#  'Koningin Beatrixschool',
#  'Tamarschool',
#  'Islamitische Basisschool Yunus Emre',
#  'Islamitische Basisschool Yunus Emre',
#  'Yunus Emre',
#  'Yunus Emre - Schalk Burgerstraat',
#  'Al Qoeba',
#  'Algemene Hindoeschool',
#  'Rooms Katholieke Basisschool De Zuidwester',
#  'Rosa basisschool',
#  'Basisschool De Buutplaats',
#  'Petrus Dondersschool',
#  'RK Basisschool Christoffel',
#  'Montessorischool Leidschenveen',
#  'Montessorischool Houtwijk',
#  'Christelijke Montessorischool De Abeel',
#  'De Walvis',
#  'De Kleine Keizer',
#  'De Kleine Keizer',
#  'Basisschool Archipel',
#  'Dalton KC Helen Parkhurst',
#  'De Spoorzoeker',
#  'dr. Willem Dreesschool',
#  'Basisschool Valkenbos Montessori-School',
#  'Basisschool Bohemen Kijkduin',
#  'Benoordenhout',
#  'De Baanbreker',
#  'PC Hooftschool',
#  'Startpunt International',
#  'obs Galvani',
#  'Maria Montessorischool',
#  'Openbare Basisschool Anne Frank',
#  'De Zonnebloem',
#  'Annie MG Schmidtschool',
#  'Annie MG Schmidtschool',
#  'De Klimop',
#  'De Kameleon',
#  'Openbare Basisschool Max Velthuijs',
#  'Openbare basisschool Houtwijk',
#  'Houtrustschool',
#  'Openbare Basisschool De Gelderlandschool',
#  'De Drentse Hoek',
#  'Van Ostadeschool',
#  'Erasmusschool',
#  'Openbare Basisschool Prins Willem Alexander',
#  'Springbok International',
#  'De Kleine Wereld',
#  'De La Reyschool',
#  'Het Volle Leven',
#  'Jan Ligthartschool',
#  'De Wissel',
#  'Het Galjoen',
#  'De Tweemaster',
#  'OBS De Voorsprong',
#  'De Vlierboom',
#  'De Leeuwerikhoeve',
#  'Prinses Marijkeschool',
#  'Zuidwalschool',
#  'Insp W P Blokpoelschool',
#  'School voor Speciaal Basisonderwijs De Bonte Vlinder',
#  'Eerste Nederlandse Buitenschool',
#  'School voor Speciaal Basisonderwijs De Haagse Beek',
#  'Insp S De Vriesschool',
#  'School voor Speciaal Basisonderwijs P H Schreuder',
#  'SO De Piramide',
#  'De Strandwacht, school verbonden aan het Pedologisch Instituut',
#  'De Vijver',
#  'Openbare Dalton Basisschool Waterland',
#  'Openbare Basisschool De Notenkraker',
#  'Prinses Catharina-Amaliaschool',
#  'Tyltylcentrum De Witte Vogel',
#  'Eben Haezerschool',
#  'Eerste Nederlandse Montessori School',
#  'The International School of The Hague',
#  'Europese School Den Haag',
#  'Vrije School Wonnebald',
#  'Koetsveldschool',
#  'Chr. Basisschool De Elout',
#  'Bavinckschool',
#  'School voor Speciaal Basisonderwijs Het Mozaiek',
#  'Kindcentrum Vroondaal',
#  'Prof. Mr. A. Anemaschool',
#  'Ds. W.E. den Hertogschool',
#  'Christelijke Basisschool De Ark',
#  'Protestants Christelijke Basisschool Prinsehaghe',
#  'CBS Waalse Louise de Coligny',
#  'Oranje Nassauschool voor christelijk basisonderwijs',
#  'O.G. Heldringschool',
#  'Van Hoogstratenschool',
#  'CBS Comenius',
#  'Da Costa School Christelijke Basisonderwijs',
#  'christelijke basisschool De Spiegel',
#  'Christelijk Basisschool Leyenburg',
#  'KC Da Vinci (ds. D. A. v.d. Boschschool)',
#  'P Oosterleeschool, school voor Christelijk Basisonderwijs',
#  'Dr. J.A. Gerth van  Wijkschool',
#  'Christelijke Basisschool De Vliermeent',
#  'Ds. D.J. Karresschool',
#  'Paul Krugersch voor Christelijk Basisonderwijs',
#  'Christelijke Basisschool De Ontmoeting',
#  'Jan V Nassauschool voor Protestants Christelijk Basisonderwijs',
#  'Prinses Ireneschool',
#  'Meester Schabergschool voor Christelijk Basisonderwijs',
#  'Kindcentrum Wondersteboven',
#  'De Horizon Christelijke School voor Basisonderwijs',
#  'School voor Speciaal Basisonderwijs De Springplank',
#  'CBS De Vuurtoren',
#  'Protestants Christelijke Basisschool De Oranjeschool',
#  'Protestants Christelijke Basisschool De Oranjeschool locatie De Meerpaal',
#  'De Gantel',
#  'CBS De Waterlelie',
#  'Vereniging Willem de Zwijgerschool',
#  'Octantschool Fontein',
#  'Octantschool Zonnestraal',
#  'Schoolvereniging Wolters',
#  'IVIO Instituut voor Individueel Onderwijs',
#  'Internationale basisschool Stichting Haagsche Schoolvereeniging',
#  'Willemspark',
#  'Montessori Waalsdorp',
#  'De Vrije School Den Haag',
#  'IWSTH International Waldorf School The Hague']

# %%
def perform_search_and_scroll(driver):
    try:
        # Find the element with the specified class name and click it
        button_search = driver.find_element(By.CLASS_NAME, 'zoeken-resultaten-lijst-meer')
        button_search.click()

        # Scroll to the end of the page
        driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.END)

        # Optionally, you can add a delay to give the page time to load new content
        # import time
        # time.sleep(2)  # 2 seconds of delay (adjust as needed)
        
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# %%
len(school_list_clean)
# Out:
# 162

# %%
adress_list_dirty = soup.find_all(attrs={'class': re.compile(r'zoekresultaat-adres')})
adress_list_clean = [job.text.strip() for job in adress_list_dirty]
adress_list_clean
# Out:
# ['Ruychrocklaan 340',
#  'Donker Curtiusstraat 4',
#  '2e Braamstraat 5',
#  'Gradaland 5',
#  'Parkietlaan 1',
#  'A. Kortekaasplantsoen 125',
#  'Den Helderstraat 250',
#  'Guntersteinweg 60',
#  'Westeinde 103',
#  'Weimarstraat 300',
#  'Brandtstraat 87',
#  'Bisschopstraat 3',
#  'Van Beverningkstraat 29',
#  'Bentelostraat 53',
#  'Guido Gezellestraat 51',
#  'Linnaeusstraat 12',
#  'Georges Bizetstraat 21',
#  'Vaillantlaan 230',
#  "'s-Gravenzandelaan 262",
#  'Diamanthorst 10',
#  'Amalia van Solmsstraat 157',
#  'Meester de Bruinplein 3',
#  'Hengelolaan 602',
#  'Wandelgangen 50',
#  'Paets van Troostwijkstr 87',
#  'Zweeloostraat 61',
#  'Verhulstplein 21',
#  'Laan van Poot 355',
#  'Merkusstraat 19',
#  'Adriaan Goekooplaan 13',
#  'Woonstede 98',
#  'Frits Diepenlaan 43',
#  'Laan van Wateringse Veld 462',
#  'Klaverveld 3-5',
#  'Weidevogellaan 201',
#  'Oeverwallaan 104',
#  'Windjammersingel 80',
#  'St. Barbaraweg 4',
#  'Van Ruysbroekstraat 5',
#  'Abraham van Beyerenstr 56',
#  'Prins Mauritslaan 8',
#  'Saenredamstraat 4',
#  'Fluitenbergstraat 6',
#  'Mandelaplein 2',
#  'Beresteinlaan 629',
#  'Van Damstraat 7',
#  'Schalk Burgerstraat 383',
#  'Terwestenstraat 105',
#  'Mackaystraat 6',
#  'Marterrade 312',
#  'Nijkerklaan 7',
#  'Hoefkade 677',
#  'Ambachtsgaarde 5',
#  'Madurolaan 25',
#  'Cicerostrook 1',
#  'Architect Berlagelaan 125',
#  'Abeelstraat 30',
#  'Eendenplein 5',
#  'Alphons Diepenbrockhof 79',
#  'Loosduinse Uitleg 10',
#  'Atjehstraat 31',
#  'Baambruggestraat 2 -4',
#  'Busken Huetstraat 22 -24',
#  'Bresterstraat 15',
#  'Cederstraat 29',
#  'Daltonplantsoen 6',
#  'Dreibholtzstraat 2',
#  'Elboogstraat 68',
#  'Escamplaan 65',
#  'Suze Robertsonstraat 103',
#  'Galvanistraat 43',
#  'Zevenwoudenlaan 197',
#  'Beresteinlaan 267',
#  'Hyacinthweg 5',
#  'Jacob de Graefflaan 10',
#  'Van Hoornbeekstraat 5',
#  'Cartesiusstraat 2 -4',
#  'Ketelstraat 101',
#  'Da Costastraat 40',
#  'Mari Andriessenstraat 42',
#  'Nachtegaalplein 19 A',
#  'Nijkerklaan 9',
#  'Oosterhesselenstraat 586',
#  'Van Ostadestraat 245',
#  'Ambachtsgaarde 1',
#  'Laakweg 199',
#  'Pretoriusstraat 123',
#  'Van Ruysbroekstraat 7',
#  'De La Reyweg 212',
#  'Rijslag 21',
#  'Slicherstraat 5 -7',
#  'Steenwijklaan 10',
#  'Anna Blamanplein 15',
#  'Tesselsestraat 75 A',
#  'Ruijsdaelstraat 11',
#  'Vlierboomstraat 366',
#  'Walenburg 25',
#  'Abraham van Beyerenstr 1 c',
#  'Zuidwal 47',
#  'Haardstede 1',
#  'Aucubastraat 3',
#  'Doorniksestraat 28',
#  'Bentelostraat 59',
#  'Heliotrooplaan 35',
#  'Hendrick Goltziusstraat 5',
#  'Melis Stokelaan 1189',
#  'Paddepad 8',
#  'Kikkerbeetlaan 27',
#  'Eendenplein 1',
#  'Eksterhof 2',
#  'Cicerostrook 9',
#  'Melis Stokelaan 1189',
#  'Paulus Buijsstraat 51',
#  'Laan van Poot 353',
#  'Wijndaelerduin 1',
#  'Houtrustweg 2',
#  'Mozartlaan 189',
#  'Zwaardvegersgaarde 25',
#  'Copernicusstraat 159',
#  'Acaciastraat 141',
#  'Van den Eyndestraat 24',
#  'Bertrand Russelllaan 16-18',
#  'Eindstede 4',
#  'Luxemburgstraat 7',
#  'Maarsbergenstraat 169 c',
#  'Prinsegracht 182',
#  'Ametisthorst 421',
#  'Weissenbruchstraat 119',
#  'IJsvogelplein 10',
#  'Spaarwaterstraat 21',
#  'Colensostraat 6',
#  'Hollanderstraat 21',
#  'Van de Spiegelstraat 23',
#  'Edamstraat 2',
#  'Erasmusweg 68',
#  'Pieter Langendijkstraat 81',
#  'Withuysstraat 2',
#  'Vlierboomstraat 362',
#  'Naarderstraat 170',
#  'Fischerstraat 133',
#  'Draaistraat 16',
#  'Zaanstraat 25',
#  'Slicherstraat 6',
#  'Sirtemastraat 400',
#  'Laurens Reaelstraat 10',
#  'Paets van Troostwijkstr 93',
#  'Pachtersdreef 3',
#  'Stevinstraat 65 E',
#  'Westduinweg 127',
#  'Tesselsestraat 75',
#  'Laan van Wateringse Veld 925',
#  'Laantje van Salland 32',
#  'Gentsestraat 124',
#  'Steenuillaan 2',
#  'Oeverwallaan 108',
#  'Utenbroekestraat 2',
#  'Laan van Poot 91',
#  'Nassaulaan 26',
#  'Frederikstraat 28',
#  'Utenbroekestraat 6',
#  'Abbenbroekweg 7',
#  '2e Messstraat 31']

# %%
len(adress_list_clean)
# Out:
# 162

# %%
details_list_dirty = soup.find_all(attrs={'class': re.compile(r'zoekresultaat-details')})
details_list_clean = [job.text.strip() for job in details_list_dirty]
details_list_clean
# Out:
# ['Confessioneel overigSpeciaal onderwijs87 leerlingen',
#  'KatholiekBasisonderwijs469 leerlingen',
#  'KatholiekBasisonderwijs204 leerlingen',
#  'KatholiekBasisonderwijs220 leerlingenMontessori',
#  'KatholiekBasisonderwijs251 leerlingen',
#  'Algemeen bijzonderBasisonderwijs387 leerlingen',
#  'KatholiekBasisonderwijs284 leerlingenOntwikkelingsgericht Onderwijs',
#  'KatholiekBasisonderwijs365 leerlingen',
#  'KatholiekBasisonderwijs350 leerlingen',
#  'KatholiekBasisonderwijs123 leerlingen',
#  'KatholiekBasisonderwijs774 leerlingen',
#  'KatholiekBasisonderwijs434 leerlingen',
#  'Confessioneel overigBasisonderwijs391 leerlingen',
#  'KatholiekBasisonderwijs345 leerlingen',
#  'KatholiekBasisonderwijs347 leerlingen',
#  'KatholiekBasisonderwijs665 leerlingen',
#  'KatholiekBasisonderwijs211 leerlingen',
#  'KatholiekBasisonderwijs673 leerlingen',
#  'Algemeen bijzonderBasisonderwijs141 leerlingen',
#  'KatholiekBasisonderwijs310 leerlingenOntwikkelingsgericht Onderwijs',
#  'KatholiekBasisonderwijs405 leerlingen',
#  'KatholiekBasisonderwijs269 leerlingen',
#  'KatholiekSpeciaal onderwijs63 leerlingen',
#  'KatholiekSpeciaal basisonderwijs124 leerlingen',
#  'KatholiekSpeciaal basisonderwijs128 leerlingenEigen tempo werkwijze',
#  'Algemeen bijzonderBasisonderwijs195 leerlingen',
#  'Algemeen bijzonderBasisonderwijs223 leerlingen',
#  'Algemeen bijzonderBasisonderwijs241 leerlingen',
#  'Algemeen bijzonderBasisonderwijs414 leerlingen',
#  'Algemeen bijzonderBasisonderwijs238 leerlingen',
#  'Algemeen bijzonderBasisonderwijs205 leerlingen',
#  'Prot. christelijkBasisonderwijs405 leerlingen',
#  'KatholiekBasisonderwijs821 leerlingen',
#  'SamenwerkingBasisonderwijs693 leerlingen',
#  'KatholiekBasisonderwijs545 leerlingen',
#  'KatholiekBasisonderwijs276 leerlingen',
#  'SamenwerkingSpeciaal basisonderwijs196 leerlingen',
#  'Confessioneel overigBasisonderwijs',
#  'OpenbaarSpeciaal onderwijs204 leerlingen',
#  'Confessioneel overigBasisonderwijs375 leerlingen',
#  'Prot. christelijkBasisonderwijs251 leerlingen',
#  'Prot. christelijkBasisonderwijs317 leerlingen',
#  'Prot. christelijkBasisonderwijs395 leerlingen',
#  'Confessioneel overigBasisonderwijs256 leerlingen',
#  'Confessioneel overigBasisonderwijs337 leerlingen',
#  'Confessioneel overigBasisonderwijs362 leerlingen',
#  'Confessioneel overigBasisonderwijs273 leerlingen',
#  'Confessioneel overigBasisonderwijs287 leerlingen',
#  'Confessioneel overigBasisonderwijs203 leerlingen',
#  'KatholiekBasisonderwijs378 leerlingen',
#  'KatholiekBasisonderwijs261 leerlingen',
#  'KatholiekBasisonderwijs180 leerlingen',
#  'KatholiekBasisonderwijs237 leerlingen',
#  'KatholiekBasisonderwijs457 leerlingen',
#  'Algemeen bijzonderBasisonderwijs428 leerlingenMontessori',
#  'Algemeen bijzonderBasisonderwijs237 leerlingenMontessori',
#  'Prot. christelijkBasisonderwijs302 leerlingenMontessori',
#  'KatholiekBasisonderwijs363 leerlingen',
#  'OpenbaarBasisonderwijs143 leerlingen',
#  'OpenbaarBasisonderwijs146 leerlingen',
#  'OpenbaarBasisonderwijs223 leerlingen',
#  'OpenbaarBasisonderwijs333 leerlingenDalton',
#  'OpenbaarBasisonderwijs181 leerlingen',
#  'OpenbaarBasisonderwijs279 leerlingen',
#  'OpenbaarBasisonderwijs303 leerlingenMontessori',
#  'OpenbaarBasisonderwijs434 leerlingen',
#  'OpenbaarBasisonderwijs207 leerlingen',
#  'OpenbaarBasisonderwijs137 leerlingen',
#  'OpenbaarBasisonderwijs246 leerlingen',
#  'OpenbaarBasisonderwijs170 leerlingen',
#  'OpenbaarBasisonderwijs452 leerlingen',
#  'OpenbaarBasisonderwijs543 leerlingenMontessori',
#  'OpenbaarBasisonderwijs557 leerlingen',
#  'OpenbaarBasisonderwijs432 leerlingen',
#  'OpenbaarBasisonderwijs357 leerlingen',
#  'OpenbaarBasisonderwijs219 leerlingen',
#  'OpenbaarBasisonderwijs199 leerlingen',
#  'OpenbaarBasisonderwijs175 leerlingen',
#  'OpenbaarBasisonderwijs147 leerlingenOntwikkelingsgericht Onderwijs',
#  'OpenbaarBasisonderwijs237 leerlingen',
#  'OpenbaarBasisonderwijs239 leerlingen',
#  'OpenbaarBasisonderwijs258 leerlingenOntwikkelingsgericht Onderwijs',
#  'OpenbaarBasisonderwijs208 leerlingen',
#  'OpenbaarBasisonderwijs396 leerlingen',
#  'OpenbaarBasisonderwijs358 leerlingen',
#  'OpenbaarBasisonderwijs342 leerlingen',
#  'OpenbaarBasisonderwijs405 leerlingen',
#  'OpenbaarBasisonderwijs344 leerlingen',
#  'OpenbaarBasisonderwijs420 leerlingen',
#  'OpenbaarBasisonderwijs572 leerlingen',
#  'OpenbaarBasisonderwijs266 leerlingen',
#  'OpenbaarBasisonderwijs374 leerlingen',
#  'OpenbaarBasisonderwijs198 leerlingen',
#  'OpenbaarBasisonderwijs107 leerlingen',
#  'OpenbaarBasisonderwijs271 leerlingen',
#  'OpenbaarBasisonderwijs212 leerlingen',
#  'OpenbaarBasisonderwijs233 leerlingen',
#  'OpenbaarBasisonderwijs322 leerlingen',
#  'OpenbaarBasisonderwijs244 leerlingen',
#  'OpenbaarSpeciaal onderwijs109 leerlingen',
#  'OpenbaarSpeciaal basisonderwijs245 leerlingen',
#  'OpenbaarSpeciaal onderwijs101 leerlingen',
#  'OpenbaarSpeciaal basisonderwijs132 leerlingen',
#  'OpenbaarSpeciaal onderwijs103 leerlingen',
#  'OpenbaarSpeciaal basisonderwijs130 leerlingen',
#  'OpenbaarSpeciaal onderwijs97 leerlingenEigen tempo werkwijze',
#  'OpenbaarSpeciaal onderwijs271 leerlingen',
#  'OpenbaarBasisonderwijs374 leerlingenDalton',
#  'OpenbaarBasisonderwijs250 leerlingenDalton',
#  'OpenbaarBasisonderwijs206 leerlingen',
#  'OpenbaarBasisonderwijs342 leerlingen',
#  'Algemeen bijzonderSpeciaal onderwijs73 leerlingen',
#  'Prot. christelijkBasisonderwijs123 leerlingen',
#  'Algemeen bijzonderBasisonderwijs350 leerlingenMontessori',
#  'Algemeen bijzonderBasisonderwijs459 leerlingen',
#  'Algemeen bijzonderBasisonderwijs907 leerlingen',
#  'Algemeen bijzonderBasisonderwijs243 leerlingenVrijeschool',
#  'Prot. christelijkSpeciaal onderwijs98 leerlingen',
#  'Prot. christelijkBasisonderwijs215 leerlingen',
#  'Prot. christelijkBasisonderwijs212 leerlingen',
#  'Prot. christelijkSpeciaal basisonderwijs95 leerlingen',
#  'Prot. christelijkBasisonderwijs562 leerlingenIPC',
#  'Prot. christelijkBasisonderwijs395 leerlingen',
#  'Prot. christelijkBasisonderwijs265 leerlingen',
#  'Prot. christelijkBasisonderwijs362 leerlingen',
#  'Prot. christelijkBasisonderwijs171 leerlingenJeelo',
#  'Prot. christelijkBasisonderwijs116 leerlingen',
#  'Prot. christelijkBasisonderwijs324 leerlingen',
#  'Prot. christelijkBasisonderwijs397 leerlingen',
#  'Prot. christelijkBasisonderwijs148 leerlingen',
#  'Prot. christelijkBasisonderwijs151 leerlingen',
#  'Prot. christelijkBasisonderwijs205 leerlingen',
#  'Prot. christelijkBasisonderwijs233 leerlingen',
#  'Prot. christelijkBasisonderwijs455 leerlingen',
#  'Prot. christelijkBasisonderwijs287 leerlingen',
#  'Prot. christelijkBasisonderwijs332 leerlingen',
#  'Prot. christelijkBasisonderwijs334 leerlingen',
#  'Prot. christelijkBasisonderwijs425 leerlingen',
#  'Prot. christelijkBasisonderwijs275 leerlingen',
#  'Prot. christelijkBasisonderwijs167 leerlingen',
#  'Prot. christelijkBasisonderwijs207 leerlingen',
#  'Prot. christelijkBasisonderwijs395 leerlingen',
#  'Prot. christelijkBasisonderwijs190 leerlingen',
#  'Prot. christelijkBasisonderwijs89 leerlingen',
#  'Prot. christelijkBasisonderwijs168 leerlingenJeelo',
#  'Prot. christelijkBasisonderwijs330 leerlingen',
#  'Prot. christelijkSpeciaal basisonderwijs147 leerlingen',
#  'Prot. christelijkBasisonderwijs178 leerlingen',
#  'Prot. christelijkBasisonderwijs254 leerlingen',
#  'Prot. christelijkBasisonderwijs170 leerlingen',
#  'Prot. christelijkBasisonderwijs445 leerlingen',
#  'Prot. christelijkBasisonderwijs436 leerlingen',
#  'OverigeBasisonderwijs444 leerlingen',
#  'Prot. christelijkBasisonderwijs404 leerlingen',
#  'Prot. christelijkBasisonderwijs354 leerlingen',
#  'Algemeen bijzonderBasisonderwijs420 leerlingen',
#  'Algemeen bijzonderSpeciaal basisonderwijs82 leerlingen',
#  'Algemeen bijzonderBasisonderwijs872 leerlingen',
#  'Algemeen bijzonderBasisonderwijs242 leerlingen',
#  'Algemeen bijzonderBasisonderwijs287 leerlingenMontessori',
#  'Algemeen bijzonderBasisonderwijs365 leerlingenVrijeschool',
#  'Algemeen bijzonderBasisonderwijs78 leerlingen']

# %%
import re

details_list_clean


pattern = r'\d+'


number_of_students = [re.search(pattern, item).group() if re.search(pattern, item) else '' for item in details_list_clean]

number_of_students
# Out:
# ['87',
#  '469',
#  '204',
#  '220',
#  '251',
#  '387',
#  '284',
#  '365',
#  '350',
#  '123',
#  '774',
#  '434',
#  '391',
#  '345',
#  '347',
#  '665',
#  '211',
#  '673',
#  '141',
#  '310',
#  '405',
#  '269',
#  '63',
#  '124',
#  '128',
#  '195',
#  '223',
#  '241',
#  '414',
#  '238',
#  '205',
#  '405',
#  '821',
#  '693',
#  '545',
#  '276',
#  '196',
#  '',
#  '204',
#  '375',
#  '251',
#  '317',
#  '395',
#  '256',
#  '337',
#  '362',
#  '273',
#  '287',
#  '203',
#  '378',
#  '261',
#  '180',
#  '237',
#  '457',
#  '428',
#  '237',
#  '302',
#  '363',
#  '143',
#  '146',
#  '223',
#  '333',
#  '181',
#  '279',
#  '303',
#  '434',
#  '207',
#  '137',
#  '246',
#  '170',
#  '452',
#  '543',
#  '557',
#  '432',
#  '357',
#  '219',
#  '199',
#  '175',
#  '147',
#  '237',
#  '239',
#  '258',
#  '208',
#  '396',
#  '358',
#  '342',
#  '405',
#  '344',
#  '420',
#  '572',
#  '266',
#  '374',
#  '198',
#  '107',
#  '271',
#  '212',
#  '233',
#  '322',
#  '244',
#  '109',
#  '245',
#  '101',
#  '132',
#  '103',
#  '130',
#  '97',
#  '271',
#  '374',
#  '250',
#  '206',
#  '342',
#  '73',
#  '123',
#  '350',
#  '459',
#  '907',
#  '243',
#  '98',
#  '215',
#  '212',
#  '95',
#  '562',
#  '395',
#  '265',
#  '362',
#  '171',
#  '116',
#  '324',
#  '397',
#  '148',
#  '151',
#  '205',
#  '233',
#  '455',
#  '287',
#  '332',
#  '334',
#  '425',
#  '275',
#  '167',
#  '207',
#  '395',
#  '190',
#  '89',
#  '168',
#  '330',
#  '147',
#  '178',
#  '254',
#  '170',
#  '445',
#  '436',
#  '444',
#  '404',
#  '354',
#  '420',
#  '82',
#  '872',
#  '242',
#  '287',
#  '365',
#  '78']
